# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv("DatasetRecomendadorCarreras_1.csv")

# %%
print(df.head())
# Out:
#                                               Dibujo  Baile  Canto  Deportes  \
# 0  No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,N...    NaN    NaN       NaN
# 1  No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,N...    NaN    NaN       NaN
# 2  No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,N...    NaN    NaN       NaN
# 3  No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,N...    NaN    NaN       NaN
# 4  No,No,No,No,No,No,No,No,No,No,No,No,No,No,No,N...    NaN    NaN       NaN
#
#    Videojuegos  Actuación  Viajar  Jardinería  Animales  Fotografía  ...  \
# 0          NaN        NaN     NaN         NaN       NaN         NaN  ...
# 1          NaN        NaN     NaN         NaN       NaN         NaN  ...
# 2          NaN        NaN     NaN         NaN       NaN         NaN  ...
# 3          NaN        NaN     NaN         NaN       NaN         NaN  ...
# 4          NaN        NaN     NaN         NaN       NaN         NaN  ...
#
# ...
